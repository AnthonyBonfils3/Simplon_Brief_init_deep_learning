# %% [markdown]
# Data: https://data.world/crowdflower/sentiment-analysis-in-text

# %%
# %matplotlib notebook
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

import pickle

import matplotlib.pyplot as plt
import pandas as pd

from collections import Counter

from utils.text_utils import clean_sentence, encode_sentence

# %%
data_file = 'datas/text_emotion.csv'
data = pd.read_csv(data_file)

# %%
data.describe(include='all')
# Out:
#             tweet_id sentiment       author  \
# count   4.000000e+04     40000        40000
# unique           NaN        13        33871
# top              NaN   neutral  MissxMarisa
# freq             NaN      8638           23
# mean    1.845184e+09       NaN          NaN
# std     1.188579e+08       NaN          NaN
# min     1.693956e+09       NaN          NaN
# 25%     1.751431e+09       NaN          NaN
# 50%     1.855443e+09       NaN          NaN
# 75%     1.962781e+09       NaN          NaN
# max     1.966441e+09       NaN          NaN
#
#                                                   content
# count                                               40000
# unique                                              39827
# top     I just received a mothers day card from my lov...
# freq                                                   14
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
data.isnull().sum()
# Out:
# tweet_id     0
# sentiment    0
# author       0
# content      0
# dtype: int64

# %%
data['sentiment'].value_counts().plot(kind='bar', rot=60)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
data.head()
# Out:
#      tweet_id   sentiment       author  \
# 0  1956967341       empty   xoshayzers
# 1  1956967666     sadness    wannamama
# 2  1956967696     sadness    coolfunky
# 3  1956967789  enthusiasm  czareaquino
# 4  1956968416     neutral    xkilljoyx
#
#                                              content
# 0  @tiffanylue i know  i was listenin to bad habi...
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4  @dannycastillo We want to trade with someone w...

# %%
# clean content (remove handles, links, punctuation, stop words, and apply stemmer)
data['clean_content'] = data['content'].apply(clean_sentence)
data.head()
# Out:
#      tweet_id   sentiment       author  \
# 0  1956967341       empty   xoshayzers
# 1  1956967666     sadness    wannamama
# 2  1956967696     sadness    coolfunky
# 3  1956967789  enthusiasm  czareaquino
# 4  1956968416     neutral    xkilljoyx
#
#                                              content  \
# 0  @tiffanylue i know  i was listenin to bad habi...
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4  @dannycastillo We want to trade with someone w...
#
#                                     clean_content
# 0  know listenin bad habit ear start freakin part
# 1            layin bed headach ughhh  waitin cal
# 2                     fun ceremony  gloom friday
# 3                           want hang friend soon
# 4              want trad someon houston ticket on

# %%
# look at distribution of most common words
counter = Counter()
for _, row in data.iterrows():
    counter.update(row['clean_content'].split())
counts = pd.DataFrame(counter.most_common(), columns=['word', 'count'])
counts['cumulative'] = counts['count'].cumsum() / counts['count'].sum()

counts.plot(y='cumulative', logx=True, grid=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# make vocabulary lookup from top 95% of most common words
cutoff = .95
vocab = dict()
for idx, row in counts.iterrows():
    if row['cumulative'] > cutoff:
        break
    vocab[row['word']] = idx

# check vocab length
len(vocab)
# Out:
# 8171

# %%
# encode words to ids
data['encoded_content'] = data['clean_content'].apply(encode_sentence, args=(vocab,))
data.head()
# Out:
#      tweet_id   sentiment       author  \
# 0  1956967341       empty   xoshayzers
# 1  1956967666     sadness    wannamama
# 2  1956967696     sadness    coolfunky
# 3  1956967789  enthusiasm  czareaquino
# 4  1956968416     neutral    xkilljoyx
#
#                                              content  \
# 0  @tiffanylue i know  i was listenin to bad habi...
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4  @dannycastillo We want to trade with someone w...
#
#                                     clean_content  \
# 0  know listenin bad habit ear start freakin part
# 1            layin bed headach ughhh  waitin cal
# 2                     fun ceremony  gloom friday
# 3                           want hang friend soon
# 4              want trad someon houston ticket on
#
#                            encoded_content
# 0  [17, 2478, 55, 2646, 109, 83, 968, 355]
# 1          [6171, 80, 290, 1309, 1792, 88]
# 2                    [48, 3092, 1275, 140]
# 3                        [19, 343, 61, 99]
# 4           [19, 1432, 166, 1949, 369, 14]

# %%
# find max sequence length
max(data['encoded_content'].apply(len))
max_sequence_length = 25

# %%
# encode label values
labels = {value: idx for idx, value in enumerate(data['sentiment'].unique())}
labels
# Out:
# {'empty': 0,
#  'sadness': 1,
#  'enthusiasm': 2,
#  'neutral': 3,
#  'worry': 4,
#  'surprise': 5,
#  'love': 6,
#  'fun': 7,
#  'hate': 8,
#  'happiness': 9,
#  'boredom': 10,
#  'relief': 11,
#  'anger': 12}

# %%
data['label'] = data['sentiment'].apply(lambda x: labels[x])
data.head()
# Out:
#      tweet_id   sentiment       author  \
# 0  1956967341       empty   xoshayzers
# 1  1956967666     sadness    wannamama
# 2  1956967696     sadness    coolfunky
# 3  1956967789  enthusiasm  czareaquino
# 4  1956968416     neutral    xkilljoyx
#
#                                              content  \
# 0  @tiffanylue i know  i was listenin to bad habi...
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4  @dannycastillo We want to trade with someone w...
#
#                                     clean_content  \
# 0  know listenin bad habit ear start freakin part
# 1            layin bed headach ughhh  waitin cal
# 2                     fun ceremony  gloom friday
# 3                           want hang friend soon
# 4              want trad someon houston ticket on
#
#                            encoded_content  label
# 0  [17, 2478, 55, 2646, 109, 83, 968, 355]      0
# 1          [6171, 80, 290, 1309, 1792, 88]      1
# 2                    [48, 3092, 1275, 140]      1
# 3                        [19, 343, 61, 99]      2
# 4           [19, 1432, 166, 1949, 369, 14]      3

# %%
# save processed file
processed_datafile = './pickles/processed_emotions.pkl'

processed_data = data[['label', 'encoded_content']]
processed_data.columns = ['label', 'sequence']
processed_data.to_pickle(processed_datafile)
processed_data.head()
# Out:
#    label                                 sequence
# 0      0  [17, 2478, 55, 2646, 109, 83, 968, 355]
# 1      1          [6171, 80, 290, 1309, 1792, 88]
# 2      1                    [48, 3092, 1275, 140]
# 3      2                        [19, 343, 61, 99]
# 4      3           [19, 1432, 166, 1949, 369, 14]

# %%
# save data params
data_params_file = './pickles/data_params.pkl'

class_lookup = {v: k for k, v in labels.items()}
params = dict(max_sequence_length=max_sequence_length, vocab=vocab, labels=class_lookup)

with open(data_params_file, 'wb') as f:
    pickle.dump(params, f)
